# %% [markdown]
# Original code taken from [https://gist.github.com/EderSantana/c7222daa328f0e885093](https://gist.github.com/EderSantana/c7222daa328f0e885093)

# %% [markdown]
# # Installation
# To be able to run the animation below, make sure you have the latest version of matplotlib, by running `pip3 install matplotlib --upgrade`

# %%
# %matplotlib inline
import json
import numpy as np
import random
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import sgd
import matplotlib.pyplot as plt
import matplotlib.animation
import IPython.display
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Define the game environment and replay classes
# The idea in this Catch game is that there is fruit falling, and the user gets to move a basket so that they catch the fruit. If they catch it, they win and the game is over. If they miss it, they lose and the game is over. We are trying to teach the computer to play this game.

# %%
class Catch(object):
    def __init__(self, grid_size=10):
        '''
        Input: grid_size (length of the side of the canvas)
        
        Initializes internal state.
        '''
        self.grid_size = grid_size
        self.min_basket_center = 1
        self.max_basket_center = self.grid_size-2
        self.reset()

    def _update_state(self, action):
        '''
        Input: action (0 for left, 1 for stay, 2 for right)
        
        Moves basket according to action. Moves fruit down. Updates state to reflect these movements
        '''
        if action == 0:  # left
            movement = -1
        elif action == 1:  # stay
            movement = 0
        elif action == 2: # right
            movement = 1
        else:
            raise Exception('Invalid action {}'.format(action))
        fruit_x, fruit_y, basket_center = self.state
        # move the basket unless this would move it off the edge of the grid
        new_basket_center = min(max(self.min_basket_center, basket_center + movement), self.max_basket_center)
        # move fruit down
        fruit_y += 1
        out = np.asarray([fruit_x, fruit_y, new_basket_center])
        self.state = out

    def _draw_state(self):
        '''
        Returns a 2D numpy array with 1s (white squares) at the locations of the fruit and basket and
        0s (black squares) everywhere else.
        '''
        im_size = (self.grid_size, self.grid_size)
        canvas = np.zeros(im_size)
        
        fruit_x, fruit_y, basket_center = self.state
        canvas[fruit_y, fruit_x] = 1  # draw fruit
        canvas[-1, basket_center-1:basket_center + 2] = 1  # draw 3-pixel basket
        return canvas

    def _get_reward(self):
        '''
        Returns 1 if the fruit was caught, -1 if it was dropped, and 0 if it is still in the air.
        '''
        fruit_x, fruit_y, basket_center = self.state
        if fruit_y == self.grid_size-1:
            if abs(fruit_x - basket_center) <= 1:
                return 1 # it caught the fruit
            else:
                return -1 # it dropped the fruit
        else:
            return 0 # the fruit is still in the air

    def observe(self):
        '''
        Returns the current canvas, as a 1D array.
        '''
        canvas = self._draw_state()
        return canvas.reshape((1, -1))

    def act(self, action):
        '''
        Input: action (0 for left, 1 for stay, 2 for right)
        
        Returns:
            current canvas (as a 1D array)
            reward received after this action
            True if game is over and False otherwise
        '''
        self._update_state(action)
        observation = self.observe()
        reward = self._get_reward()
        game_over = (reward != 0) # if the reward is zero, the fruit is still in the air
        return observation, reward, game_over

    def reset(self):
        '''
        Updates internal state
            fruit in a random column in the top row
            basket center in a random column
        '''
        fruit_x = random.randint(0, self.grid_size-1)
        fruit_y = 0
        basket_center = random.randint(self.min_basket_center, self.max_basket_center)
        self.state = np.asarray([fruit_x, fruit_y, basket_center])


class ExperienceReplay(object):
    def __init__(self, max_memory=100, discount=.9):
        self.max_memory = max_memory
        self.memory = list()
        self.discount = discount

    def remember(self, states, game_over):
        '''
        Input:
            states: [starting_observation, action_taken, reward_received, new_observation]
            game_over: boolean
        Add the states and game over to the internal memory array. If the array is longer than
        self.max_memory, drop the oldest memory
        '''
        self.memory.append([states, game_over])
        if len(self.memory) > self.max_memory:
            del self.memory[0]

    def get_batch(self, model, batch_size=10):
        '''
        Randomly chooses batch_size memories, possibly repeating.
        For each of these memories, updates the models current best guesses about the value of taking a
            certain action from the starting state, based on the reward received and the model's current
            estimate of how valuable the new state is.
        '''
        len_memory = len(self.memory)
        num_actions = model.output_shape[-1] # the number of possible actions
        env_dim = self.memory[0][0][0].shape[1] # the number of pixels in the image
        input_size = min(len_memory, batch_size)
        inputs = np.zeros((input_size, env_dim))
        targets = np.zeros((input_size, num_actions))
        for i, idx in enumerate(np.random.randint(0, len_memory, size=input_size)):
            starting_observation, action_taken, reward_received, new_observation = self.memory[idx][0]
            game_over = self.memory[idx][1]

            # Set the input to the state that was observed in the game before an action was taken
            inputs[i:i+1] = starting_observation
            
            # Start with the model's current best guesses about the value of taking each action from this state
            targets[i] = model.predict(starting_observation)[0]
            
            # Now we need to update the value of the action that was taken                      
            if game_over: 
                # if the game is over, give the actual reward received
                targets[i, action_taken] = reward_received
            else:
                # if the game is not over, give the reward received (always zero in this particular game)
                # plus the maximum reward predicted for state we got to by taking this action (with a discount)
                Q_sa = np.max(model.predict(new_observation)[0])
                targets[i, action_taken] = reward_received + self.discount * Q_sa
        return inputs, targets

# %% [markdown]
# ##  Functions for creating, training, and visualizing the model

# %%
# parameters
epsilon = .1  # probability of exploration (choosing a random action instead of the current best one)
num_actions = 3  # [move_left, stay, move_right]
max_memory = 500
hidden_size = 100
batch_size = 50
grid_size = 10


def build_model():
    '''
     Returns three initialized objects: the model, the environment, and the replay.
    '''
    model = Sequential()
    model.add(Dense(hidden_size, input_shape=(grid_size**2,), activation='relu'))
    model.add(Dense(hidden_size, activation='relu'))
    model.add(Dense(num_actions))
    model.compile(sgd(lr=.2), "mse")

    # Define environment/game
    env = Catch(grid_size)

    # Initialize experience replay object
    exp_replay = ExperienceReplay(max_memory=max_memory)
    
    return model, env, exp_replay


def train_model(model, env, exp_replay, num_episodes):
    '''
    Inputs:
        model, env, and exp_replay objects as returned by build_model
        num_episodes: integer, the number of episodes that should be rolled out for training
    '''
    catch_count = 0
    for episode in range(num_episodes):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        starting_observation = env.observe()

        while not game_over:
            # get next action
            if np.random.rand() <= epsilon:
                # epsilon of the time, we just choose randomly
                action = np.random.randint(0, num_actions, size=1)
            else:
                # find which action the model currently thinks is best from this state
                q = model.predict(starting_observation)
                action = np.argmax(q[0])

            # apply action, get rewards and new state
            new_observation, reward, game_over = env.act(action)
            if reward == 1:
                catch_count += 1

            # store experience
            exp_replay.remember([starting_observation, action, reward, new_observation], game_over)

            # get data updated based on the stored experiences
            inputs, targets = exp_replay.get_batch(model, batch_size=batch_size)

            # train model on the updated data
            loss += model.train_on_batch(inputs, targets)

            starting_observation = new_observation # for next time through the loop

        # Print update from this episode
        print("Episode {:04d}/{:04d} | Loss {:.4f} | Catch count {}".format(episode, num_episodes-1, loss, catch_count))


def create_animation(model, env, num_games):
    '''
    Inputs:
        model and env objects as returned from build_model
        num_games: integer, the number of games to be included in the animation
        
    Returns: a matplotlib animation object
    '''
    # Animation code from 
    # https://matplotlib.org/examples/animation/dynamic_image.html
    # https://stackoverflow.com/questions/35532498/animation-in-ipython-notebook/46878531#46878531
    
    # First, play the games and collect all of the images for each observed state
    observations = []
    for _ in range(num_games):
        env.reset()
        observation = env.observe()
        observations.append(observation)
        game_over = False
        while game_over == False:
            q = model.predict(observation)
            action = np.argmax(q[0])
            
            # apply action, get rewards and new state
            observation, reward, game_over = env.act(action)
            observations.append(observation)
            
    fig = plt.figure()
    image = plt.imshow(np.zeros((grid_size, grid_size)),interpolation='none', cmap='gray', animated=True, vmin=0, vmax=1)
    
    def animate(observation):
        image.set_array(observation.reshape((grid_size, grid_size)))
        return [image]
   
    animation = matplotlib.animation.FuncAnimation(fig, animate, frames=observations, blit=True, )
    return animation

# %% [markdown]
# ## Let's create our model and game environment and see how it does before training

# %%
model, env, exp_replay = build_model()

# %%
animation = create_animation(model, env, num_games=10)
IPython.display.HTML(animation.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img13f50945f5194d138a92efc81ce9f64d">
#     <br>
#     <input id="_anim_slider13f50945f5194d138a92efc81ce9f64d" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim13f50945f5194d138a92efc81ce9f64d.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim13f50945f5194d138a92efc81ce9f64d.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim13f50945f5194d138a92efc81ce9f64d.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim13f50945f5194d138a92efc81ce9f64d.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim13f50945f5194d138a92efc81ce9f64d.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim13f50945f5194d138a92efc81ce9f64d.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim13f50945f5194d138a92efc81ce9f64d.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim13f50945f5194d138a92efc81ce9f64d.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim13f50945f5194d138a92efc81ce9f64d.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim13f50945f5194d138a92efc81ce9f64d.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select13f50945f5194d138a92efc81ce9f64d" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img13f50945f5194d138a92efc81ce9f64d";
#     var slider_id = "_anim_slider13f50945f5194d138a92efc81ce9f64d";
#     var loop_select_id = "_anim_loop_select13f50945f5194d138a92efc81ce9f64d";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAADQZJREFUeJzt3F9oV4X/x/H3/E1vRK1oom4OFUm3\
# Kbg5sZsu7EJFxAvdhWIQ6hhIF4p4011XNqTwT3azGy8U3EUXGUpCLqLyD7K0QCQR2mCbBgVq6ZS1\
# 9fle/KB+/HQp31rnvPXxuPvg+cwXzJ0n53yOq6pUKpUAgGQmFT0AAP4bAgZASgIGQEoCBkBKAgZA\
# SgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBK\
# AgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoC\
# BkBK1UUP4O+rqqoqegLPuOXLl//jX/Obb775x7/mRKpUKkVP4P+pqviupCdgTLSJOE1k+3frVFk+\
# biECkJKAAZCSgAGQkoABkJKAldCZM2di0aJFsXDhwujs7Cx6DkApeQqxZMbGxuKVV16Jzz77LOrq\
# 6mLFihVx4sSJaGxsHPc92Z7mIh9PIXoKsYxcgZXMpUuXYuHChbFgwYKYMmVKbN68OU6ePFn0LIDS\
# EbCSGRoairlz5/7xuq6uLoaGhgpcBFBOfhNHUl1dXdHV1VX0DIDCCFjJ1NbWxsDAwB+vBwcHo7a2\
# 9pHjOjo6oqOjIyLyfZYA8E9wC7FkVqxYETdu3Ii+vr4YGRmJ7u7u2LBhQ9GzAErHFVjJVFdXx5Ej\
# R2LNmjUxNjYW27dvj6ampqJnAZSOx+ifAW4hMtE8Ru8x+jJyCxGAlAQMgJQEDICUBAyAlAQMgJQE\
# DICU/D8w4ImyPfLO88EVGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgA\
# KQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAAp\
# CRgAKQkYACkJGAApCVjJDAwMxKpVq6KxsTGampri0KFDRU8CKKWqSqVSKXoEf7p161bcunUrWlpa\
# 4tdff43ly5fHxx9/HI2NjeO+p6qq6l9cCM8np8rycQVWMrNnz46WlpaIiJg2bVo0NDTE0NBQwasA\
# ykfASqy/vz+uXLkSK1euLHoKQOlUFz2Ax7t3715s2rQpDh48GNOnT3/kz7u6uqKrq6uAZQDl4DOw\
# Evrtt99i/fr1sWbNmtizZ88Tj/cZGEw8p8ryEbCSqVQq8eabb8ZLL70UBw8efKr3CBhMPKfK8hGw\
# kvn666/jtddei6VLl8akSf/7EeW+ffti3bp1475HwGDiOVWWj4A9AwQMJp5TZfl4ChGAlAQMgJQE\
# DICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQM\
# gJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyA\
# lAQMgJQEDICUBAyAlASspMbGxqK5uTnWr19f9BSAUhKwkjp06FA0NDQUPQOgtASshAYHB+P06dPR\
# 3t5e9BSA0hKwEtq9e3fs378/Jk3y7QEYjzNkyZw6dSpmzpwZy5cv/8vjurq6orW1NVpbW/+lZQDl\
# UlWpVCpFj+BPb7/9dhw7diyqq6vj4cOH8csvv8TGjRvj+PHj476nqqrqX1wIzyenyvIRsBL74osv\
# 4r333otTp0795XECBhPPqbJ83EIEICVXYM8AV2Aw8Zwqy8cVGAApCRgAKQkYACkJGAApCRgAKQkY\
# ACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQkYACkJGAApCRgAKQk

# %% [markdown]
# ## Now train the model and see how much better it is at catching the fruit

# %%
train_model(model, env, exp_replay, num_episodes=1000)
animation = create_animation(model, env, num_games=10)
IPython.display.HTML(animation.to_jshtml())
# Out:
# Episode 0000/0999 | Loss 0.0057 | Catch count 0
# Episode 0001/0999 | Loss 0.2673 | Catch count 1
# Episode 0002/0999 | Loss 0.2383 | Catch count 1
# Episode 0003/0999 | Loss 0.1966 | Catch count 1
# Episode 0004/0999 | Loss 0.2662 | Catch count 1
# Episode 0005/0999 | Loss 0.2100 | Catch count 1
# Episode 0006/0999 | Loss 0.1981 | Catch count 1
# Episode 0007/0999 | Loss 0.2074 | Catch count 2
# Episode 0008/0999 | Loss 0.2270 | Catch count 2
# Episode 0009/0999 | Loss 0.1945 | Catch count 3
# Episode 0010/0999 | Loss 0.2442 | Catch count 3
# Episode 0011/0999 | Loss 0.2426 | Catch count 3
# Episode 0012/0999 | Loss 0.1964 | Catch count 3
# Episode 0013/0999 | Loss 0.1678 | Catch count 3
# Episode 0014/0999 | Loss 0.1473 | Catch count 4
# Episode 0015/0999 | Loss 0.1879 | Catch count 5
# Episode 0016/0999 | Loss 0.2079 | Catch count 5
# Episode 0017/0999 | Loss 0.1975 | Catch count 6
# Episode 0018/0999 | Loss 0.1898 | Catch count 6
# Episode 0019/0999 | Loss 0.1700 | Catch count 6
# Episode 0020/0999 | Loss 0.2044 | Catch count 6
# Episode 0021/0999 | Loss 0.2418 | Catch count 7
# Episode 0022/0999 | Loss 0.1746 | Catch count 7
# Episode 0023/0999 | Loss 0.1749 | Catch count 7
# Episode 0024/0999 | Loss 0.1624 | Catch count 8
# Episode 0025/0999 | Loss 0.1697 | Catch count 9
# Episode 0026/0999 | Loss 0.2258 | Catch count 9
# Episode 0027/0999 | Loss 0.1658 | Catch count 9
# Episode 0028/0999 | Loss 0.2070 | Catch count 10
# Episode 0029/0999 | Loss 0.1702 | Catch count 11
# Episode 0030/0999 | Loss 0.1787 | Catch count 11
# Episode 0031/0999 | Loss 0.1353 | Catch count 11
# Episode 0032/0999 | Loss 0.1772 | Catch count 11
# Episode 0033/0999 | Loss 0.1321 | Catch count 11
# Episode 0034/0999 | Loss 0.1724 | Catch count 11
# Episode 0035/0999 | Loss 0.1435 | Catch count 12
# Episode 0036/0999 | Loss 0.2121 | Catch count 13
# Episode 0037/0999 | Loss 0.1140 | Catch count 13
# Episode 0038/0999 | Loss 0.1681 | Catch count 14
# Episode 0039/0999 | Loss 0.1399 | Catch count 14
# Episode 0040/0999 | Loss 0.1589 | Catch count 14
# Episode 0041/0999 | Loss 0.1506 | Catch count 15
# Episode 0042/0999 | Loss 0.2184 | Catch count 15
# Episode 0043/0999 | Loss 0.1355 | Catch count 15
# Episode 0044/0999 | Loss 0.1265 | Catch count 16
# Episode 0045/0999 | Loss 0.1634 | Catch count 17
# Episode 0046/0999 | Loss 0.1841 | Catch count 17
# Episode 0047/0999 | Loss 0.1423 | Catch count 17
# Episode 0048/0999 | Loss 0.1973 | Catch count 17
# Episode 0049/0999 | Loss 0.1572 | Catch count 18
# Episode 0050/0999 | Loss 0.1410 | Catch count 18
# Episode 0051/0999 | Loss 0.1844 | Catch count 18
# Episode 0052/0999 | Loss 0.1632 | Catch count 18
# Episode 0053/0999 | Loss 0.1372 | Catch count 19
# Episode 0054/0999 | Loss 0.1744 | Catch count 20
# Episode 0055/0999 | Loss 0.1505 | Catch count 20
# Episode 0056/0999 | Loss 0.1601 | Catch count 20
# Episode 0057/0999 | Loss 0.1649 | Catch count 21
# Episode 0058/0999 | Loss 0.1674 | Catch count 21
# Episode 0059/0999 | Loss 0.1802 | Catch count 22
# Episode 0060/0999 | Loss 0.1412 | Catch count 22
# Episode 0061/0999 | Loss 0.1848 | Catch count 22
# Episode 0062/0999 | Loss 0.2052 | Catch count 22
# Episode 0063/0999 | Loss 0.1502 | Catch count 22
# Episode 0064/0999 | Loss 0.1975 | Catch count 22
# Episode 0065/0999 | Loss 0.1578 | Catch count 22
# Episode 0066/0999 | Loss 0.1990 | Catch count 22
# Episode 0067/0999 | Loss 0.2093 | Catch count 22
# Episode 0068/0999 | Loss 0.2097 | Catch count 22
# Episode 0069/0999 | Loss 0.1833 | Catch count 23
# Episode 0070/0999 | Loss 0.1713 | Catch count 24
# Episode 0071/0999 | Loss 0.1890 | Catch count 24
# Episode 0072/0999 | Loss 0.1574 | Catch count 24
# Episode 0073/0999 | Loss 0.1520 | Catch count 25
# Episode 0074/0999 | Loss 0.2009 | Catch count 25
# Episode 0075/0999 | Loss 0.1893 | Catch count 25
# Episode 0076/0999 | Loss 0.2465 | Catch count 25
# Episode 0077/0999 | Loss 0.1573 | Catch count 26
# Episode 0078/0999 | Loss 0.1710 | Catch count 27
# Episode 0079/0999 | Loss 0.1223 | Catch count 27
# Episode 0080/0999 | Loss 0.1958 | Catch count 27
# Episode 0081/0999 | Loss 0.2104 | Catch count 28
# Episode 0082/0999 | Loss 0.1761 | Catch count 28
# Episode 0083/0999 | Loss 0.2061 | Catch count 29
# Episode 0084/0999 | Loss 0.1526 | Catch count 29
# Episode 0085/0999 | Loss 0.1882 | Catch count 29
# Episode 0086/0999 | Loss 0.1758 | Catch count 29
# Episode 0087/0999 | Loss 0.1686 | Catch count 29
# Episode 0088/0999 | Loss 0.1644 | Catch count 30
# Episode 0089/0999 | Loss 0.1304 | Catch count 30
# Episode 0090/0999 | Loss 0.1763 | Catch count 30
# Episode 0091/0999 | Loss 0.1193 | Catch count 30
# Episode 0092/0999 | Loss 0.1828 | Catch count 30
# Episode 0093/0999 | Loss 0.1616 | Catch count 30
# Episode 0094/0999 | Loss 0.1358 | Catch count 30
# Episode 0095/0999 | Loss 0.1543 | Catch count 30
# Episode 0096/0999 | Loss 0.1283 | Catch count 31
# Episode 0097/0999 | Loss 0.1273 | Catch count 31
# Episode 0098/0999 | Loss 0.1607 | Catch count 32
# Episode 0099/0999 | Loss 0.1474 | Catch count 32
# Episode 0100/0999 | Loss 0.1687 | Catch count 33
# Episode 0101/0999 | Loss 0.1411 | Catch count 33
# Episode 0102/0999 | Loss 0.1138 | Catch count 33
# Episode 0103/0999 | Loss 0.1327 | Catch count 34
# Episode 0104/0999 | Loss 0.1173 | Catch count 35
# Episode 0105/0999 | Loss 0.1459 | Catch count 36
# Episode 0106/0999 | Loss 0.1077 | Catch count 36
# Episode 0107/0999 | Loss 0.1567 | Catch count 36
# Episode 0108/0999 | Loss 0.1206 | Catch count 36
# Episode 0109/0999 | Loss 0.1593 | Catch count 36
# Episode 0110/0999 | Loss 0.1439 | Catch count 37
# Episode 0111/0999 | Loss 0.1452 | Catch count 37
# Episode 0112/0999 | Loss 0.1312 | Catch count 37
# Episode 0113/0999 | Loss 0.1453 | Catch count 38
# Episode 0114/0999 | Loss 0.1109 | Catch count 38
# Episode 0115/0999 | Loss 0.1262 | Catch count 38
# Episode 0116/0999 | Loss 0.1207 | Catch count 39
# Episode 0117/0999 | Loss 0.1087 | Catch count 39
# Episode 0118/0999 | Loss 0.1619 | Catch count 39
# Episode 0119/0999 | Loss 0.1354 | Catch count 39
# Episode 0120/0999 | Loss 0.1080 | Catch count 40
# Episode 0121/0999 | Loss 0.1520 | Catch count 40
# Episode 0122/0999 | Loss 0.1282 | Catch count 40
# Episode 0123/0999 | Loss 0.1365 | Catch count 40
# Episode 0124/0999 | Loss 0.1361 | Catch count 41
# Episode 0125/0999 | Loss 0.1040 | Catch count 42
# Episode 0126/0999 | Loss 0.1305 | Catch count 42
# Episode 0127/0999 | Loss 0.1370 | Catch count 42
# Episode 0128/0999 | Loss 0.1581 | Catch count 42
# Episode 0129/0999 | Loss 0.1084 | Catch count 43
# Episode 0130/0999 | Loss 0.1235 | Catch count 43
# Episode 0131/0999 | Loss 0.1272 | Catch count 43
# Episode 0132/0999 | Loss 0.1501 | Catch count 43
# Episode 0133/0999 | Loss 0.1004 | Catch count 44
# Episode 0134/0999 | Loss 0.1583 | Catch count 44
# Episode 0135/0999 | Loss 0.1885 | Catch count 44
# Episode 0136/0999 | Loss 0.1374 | Catch count 44
# Episode 0137/0999 | Loss 0.0963 | Catch count 45
# Episode 0138/0999 | Loss 0.1014 | Catch count 46
# Episode 0139/0999 | Loss 0.1264 | Catch count 46
# Episode 0140/0999 | Loss 0.1060 | Catch count 47
# Episode 0141/0999 | Loss 0.1710 | Catch count 48
# Episode 0142/0999 | Loss 0.1220 | Catch count 49
# Episode 0143/0999 | Loss 0.1058 | Catch count 50
# Episode 0144/0999 | Loss 0.1463 | Catch count 51
# Episode 0145/0999 | Loss 0.1379 | Catch count 52
# Episode 0146/0999 | Loss 0.1469 | Catch count 53
# Episode 0147/0999 | Loss 0.0930 | Catch count 53
# Episode 0148/0999 | Loss 0.1372 | Catch count 53
# Episode 0149/0999 | Loss 0.1166 | Catch count 54
# Episode 0150/0999 | Loss 0.1989 | Catch count 55
# Episode 0151/0999 | Loss 0.0951 | Catch count 56
# Episode 0152/0999 | Loss 0.1367 | Catch count 56
# Episode 0153/0999 | Loss 0.1478 | Catch count 57
# Episode 0154/0999 | Loss 0.1375 | Catch count 57
# Episode 0155/0999 | Loss 0.1528 | Catch count 58
# Episode 0156/0999 | Loss 0.1206 | Catch count 59
# Episode 0157/0999 | Loss 0.1098 | Catch count 60
# Episode 0158/0999 | Loss 0.1453 | Catch count 61
# Episode 0159/0999 | Loss 0.1367 | Catch count 62
# Episode 0160/0999 | Loss 0.1015 | Catch count 62
# Episode 0161/0999 | Loss 0.1441 | Catch count 63
# Episode 0162/0999 | Loss 0.1344 | Catch count 64
# Episode 0163/0999 | Loss 0.1247 | Catch count 65
# Episode 0164/0999 | Loss 0.1001 | Catch count 65
# Episode 0165/0999 | Loss 0.1254 | Catch count 65
# Episode 0166/0999 | Loss 0.1262 | Catch count 65
# Episode 0167/0999 | Loss 0.0950 | Catch count 65
# Episode 0168/0999 | Loss 0.1028 | Catch count 66
# Episode 0169/0999 | Loss 0.1603 | Catch count 66
# Episode 0170/0999 | Loss 0.1097 | Catch count 67
# Episode 0171/0999 | Loss 0.1352 | Catch count 67
# Episode 0172/0999 | Loss 0.1493 | Catch count 68
# Episode 0173/0999 | Loss 0.1292 | Catch count 68
# Episode 0174/0999 | Loss 0.1659 | Catch count 68
# Episode 0175/0999 | Loss 0.1189 | Catch count 69
# Episode 0176/0999 | Loss 0.1271 | Catch count 70
# Episode 0177/0999 | Loss 0.1252 | Catch count 70
# Episode 0178/0999 | Loss 0.0968 | Catch count 71
# Episode 0179/0999 | Loss 0.1275 | Catch count 72
# Episode 0180/0999 | Loss 0.0822 | Catch count 73
# Episode 0181/0999 | Loss 0.1029 | Catch count 73
# Episode 0182/0999 | Loss 0.0955 | Catch count 74
# Episode 0183/0999 | Loss 0.0930 | Catch count 75
# Episode 0184/0999 | Loss 0.1242 | Catch count 75
# Episode 0185/0999 | Loss 0.1209 | Catch count 75
# Episode 0186/0999 | Loss 0.1057 | Catch count 76
# Episode 0187/0999 | Loss 0.1001 | Catch count 76
# Episode 0188/0999 | Loss 0.1213 | Catch count 77
# Episode 0189/0999 | Loss 0.1196 | Catch count 78
# Episode 0190/0999 | Loss 0.0922 | Catch count 78
# Episode 0191/0999 | Loss 0.0806 | Catch count 79
# Episode 0192/0999 | Loss 0.0776 | Catch count 80
# Episode 0193/0999 | Loss 0.0895 | Catch count 80
# Episode 0194/0999 | Loss 0.1101 | Catch count 81
# Episode 0195/0999 | Loss 0.1401 | Catch count 82
# Episode 0196/0999 | Loss 0.1557 | Catch count 83
# Episode 0197/0999 | Loss 0.1033 | Catch count 84
# Episode 0198/0999 | Loss 0.1144 | Catch count 85
# Episode 0199/0999 | Loss 0.0945 | Catch count 85
# Episode 0200/0999 | Loss 0.0977 | Catch count 86
# Episode 0201/0999 | Loss 0.0809 | Catch count 86
# Episode 0202/0999 | Loss 0.0808 | Catch count 87
# Episode 0203/0999 | Loss 0.1044 | Catch count 87
# Episode 0204/0999 | Loss 0.0625 | Catch count 88
# Episode 0205/0999 | Loss 0.0649 | Catch count 88
# Episode 0206/0999 | Loss 0.0924 | Catch count 88
# Episode 0207/0999 | Loss 0.0982 | Catch count 88
# Episode 0208/0999 | Loss 0.0884 | Catch count 89
# Episode 0209/0999 | Loss 0.0999 | Catch count 90
# Episode 0210/0999 | Loss 0.0707 | Catch count 91
# Episode 0211/0999 | Loss 0.0787 | Catch count 92
# Episode 0212/0999 | Loss 0.0682 | Catch count 93
# Episode 0213/0999 | Loss 0.0800 | Catch count 94
# Episode 0214/0999 | Loss 0.0682 | Catch count 94
# Episode 0215/0999 | Loss 0.0575 | Catch count 94
# Episode 0216/0999 | Loss 0.0710 | Catch count 94
# Episode 0217/0999 | Loss 0.0709 | Catch count 95
# Episode 0218/0999 | Loss 0.0749 | Catch count 96
# Episode 0219/0999 | Loss 0.0773 | Catch count 96
# Episode 0220/0999 | Loss 0.0722 | Catch count 96
# Episode 0221/0999 | Loss 0.0583 | Catch count 97
# Episode 0222/0999 | Loss 0.0827 | Catch count 97
# Episode 0223/0999 | Loss 0.0696 | Catch count 98
# Episode 0224/0999 | Loss 0.0665 | Catch count 99
# Episode 0225/0999 | Loss 0.0642 | Catch count 100
# Episode 0226/0999 | Loss 0.0829 | Catch count 101
# Episode 0227/0999 | Loss 0.0946 | Catch count 101
# Episode 0228/0999 | Loss 0.0538 | Catch count 101
# Episode 0229/0999 | Loss 0.0718 | Catch count 101
# Episode 0230/0999 | Loss 0.0610 | Catch count 101
# Episode 0231/0999 | Loss 0.0574 | Catch count 102
# Episode 0232/0999 | Loss 0.0765 | Catch count 103
# Episode 0233/0999 | Loss 0.0637 | Catch count 104
# Episode 0234/0999 | Loss 0.0747 | Catch count 104
# Episode 0235/0999 | Loss 0.1066 | Catch count 105
# Episode 0236/0999 | Loss 0.1215 | Catch count 105
# Episode 0237/0999 | Loss 0.0888 | Catch count 106
# Episode 0238/0999 | Loss 0.1014 | Catch count 106
# Episode 0239/0999 | Loss 0.1389 | Catch count 107
# Episode 0240/0999 | Loss 0.1052 | Catch count 108
# Episode 0241/0999 | Loss 0.0908 | Catch count 109
# Episode 0242/0999 | Loss 0.1025 | Catch count 110
# Episode 0243/0999 | Loss 0.1530 | Catch count 110
# Episode 0244/0999 | Loss 0.1212 | Catch count 110
# Episode 0245/0999 | Loss 0.0629 | Catch count 111
# Episode 0246/0999 | Loss 0.0902 | Catch count 111
# Episode 0247/0999 | Loss 0.1461 | Catch count 111
# Episode 0248/0999 | Loss 0.0833 | Catch count 112
# Episode 0249/0999 | Loss 0.0979 | Catch count 113
# Episode 0250/0999 | Loss 0.0932 | Catch count 114
# Episode 0251/0999 | Loss 0.1196 | Catch count 114
# Episode 0252/0999 | Loss 0.0909 | Catch count 115
# Episode 0253/0999 | Loss 0.0870 | Catch count 116
# Episode 0254/0999 | Loss 0.0871 | Catch count 116
# Episode 0255/0999 | Loss 0.1155 | Catch count 116
# Episode 0256/0999 | Loss 0.0747 | Catch count 117
# Episode 0257/0999 | Loss 0.0665 | Catch count 117
# Episode 0258/0999 | Loss 0.0739 | Catch count 117
# Episode 0259/0999 | Loss 0.0969 | Catch count 117
# Episode 0260/0999 | Loss 0.1063 | Catch count 117
# Episode 0261/0999 | Loss 0.0655 | Catch count 118
# Episode 0262/0999 | Loss 0.0834 | Catch count 118
# Episode 0263/0999 | Loss 0.0952 | Catch count 119
# Episode 0264/0999 | Loss 0.1014 | Catch count 119
# Episode 0265/0999 | Loss 0.0602 | Catch count 119
# Episode 0266/0999 | Loss 0.0822 | Catch count 120
# Episode 0267/0999 | Loss 0.0935 | Catch count 120
# Episode 0268/0999 | Loss 0.1124 | Catch count 120
# Episode 0269/0999 | Loss 0.1235 | Catch count 121
# Episode 0270/0999 | Loss 0.1082 | Catch count 122
# Episode 0271/0999 | Loss 0.1056 | Catch count 123
# Episode 0272/0999 | Loss 0.1118 | Catch count 124
# Episode 0273/0999 | Loss 0.0827 | Catch count 124
# Episode 0274/0999 | Loss 0.0825 | Catch count 125
# Episode 0275/0999 | Loss 0.0835 | Catch count 125
# Episode 0276/0999 | Loss 0.1351 | Catch count 125
# Episode 0277/0999 | Loss 0.0953 | Catch count 126
# Episode 0278/0999 | Loss 0.0990 | Catch count 126
# Episode 0279/0999 | Loss 0.1291 | Catch count 126
# Episode 0280/0999 | Loss 0.1270 | Catch count 126
# Episode 0281/0999 | Loss 0.1002 | Catch count 126
# Episode 0282/0999 | Loss 0.1352 | Catch count 127
# Episode 0283/0999 | Loss 0.0942 | Catch count 127
# Episode 0284/0999 | Loss 0.1196 | Catch count 127
# Episode 0285/0999 | Loss 0.1134 | Catch count 128
# Episode 0286/0999 | Loss 0.0979 | Catch count 128
# Episode 0287/0999 | Loss 0.1245 | Catch count 128
# Episode 0288/0999 | Loss 0.0930 | Catch count 129
# Episode 0289/0999 | Loss 0.0910 | Catch count 130
# Episode 0290/0999 | Loss 0.0742 | Catch count 130
# Episode 0291/0999 | Loss 0.0794 | Catch count 130
# Episode 0292/0999 | Loss 0.0979 | Catch count 131
# Episode 0293/0999 | Loss 0.0858 | Catch count 131
# Episode 0294/0999 | Loss 0.0952 | Catch count 132
# Episode 0295/0999 | Loss 0.0827 | Catch count 132
# Episode 0296/0999 | Loss 0.0681 | Catch count 132
# Episode 0297/0999 | Loss 0.0556 | Catch count 133
# Episode 0298/0999 | Loss 0.0860 | Catch count 133
# Episode 0299/0999 | Loss 0.0895 | Catch count 133
# Episode 0300/0999 | Loss 0.0784 | Catch count 134
# Episode 0301/0999 | Loss 0.0751 | Catch count 134
# Episode 0302/0999 | Loss 0.0643 | Catch count 135
# Episode 0303/0999 | Loss 0.0591 | Catch count 135
# Episode 0304/0999 | Loss 0.0782 | Catch count 136
# Episode 0305/0999 | Loss 0.0629 | Catch count 137
# Episode 0306/0999 | Loss 0.0627 | Catch count 138
# Episode 0307/0999 | Loss 0.0609 | Catch count 139
# Episode 0308/0999 | Loss 0.0619 | Catch count 140
# Episode 0309/0999 | Loss 0.0548 | Catch count 141
# Episode 0310/0999 | Loss 0.0572 | Catch count 142
# Episode 0311/0999 | Loss 0.0526 | Catch count 142
# Episode 0312/0999 | Loss 0.0698 | Catch count 142
# Episode 0313/0999 | Loss 0.0649 | Catch count 143
# Episode 0314/0999 | Loss 0.0512 | Catch count 144
# Episode 0315/0999 | Loss 0.0653 | Catch count 145
# Episode 0316/0999 | Loss 0.0562 | Catch count 146
# Episode 0317/0999 | Loss 0.0689 | Catch count 147
# Episode 0318/0999 | Loss 0.0709 | Catch count 148
# Episode 0319/0999 | Loss 0.0654 | Catch count 149
# Episode 0320/0999 | Loss 0.0570 | Catch count 150
# Episode 0321/0999 | Loss 0.0708 | Catch count 150
# Episode 0322/0999 | Loss 0.0553 | Catch count 151
# Episode 0323/0999 | Loss 0.0528 | Catch count 152
# Episode 0324/0999 | Loss 0.0568 | Catch count 153
# Episode 0325/0999 | Loss 0.0577 | Catch count 154
# Episode 0326/0999 | Loss 0.0597 | Catch count 154
# Episode 0327/0999 | Loss 0.0496 | Catch count 154
# Episode 0328/0999 | Loss 0.0455 | Catch count 155
# Episode 0329/0999 | Loss 0.0433 | Catch count 156
# Episode 0330/0999 | Loss 0.0468 | Catch count 157
# Episode 0331/0999 | Loss 0.0473 | Catch count 158
# Episode 0332/0999 | Loss 0.0451 | Catch count 159
# Episode 0333/0999 | Loss 0.0459 | Catch count 160
# Episode 0334/0999 | Loss 0.0425 | Catch count 161
# Episode 0335/0999 | Loss 0.0360 | Catch count 161
# Episode 0336/0999 | Loss 0.0455 | Catch count 162
# Episode 0337/0999 | Loss 0.0298 | Catch count 163
# Episode 0338/0999 | Loss 0.0262 | Catch count 163
# Episode 0339/0999 | Loss 0.0263 | Catch count 163
# Episode 0340/0999 | Loss 0.0255 | Catch count 164
# Episode 0341/0999 | Loss 0.0317 | Catch count 164
# Episode 0342/0999 | Loss 0.0329 | Catch count 165
# Episode 0343/0999 | Loss 0.0251 | Catch count 166
# Episode 0344/0999 | Loss 0.0311 | Catch count 167
# Episode 0345/0999 | Loss 0.0322 | Catch count 167
# Episode 0346/0999 | Loss 0.0365 | Catch count 167
# Episode 0347/0999 | Loss 0.0307 | Catch count 168
# Episode 0348/0999 | Loss 0.0462 | Catch count 169
# Episode 0349/0999 | Loss 0.0384 | Catch count 169
# Episode 0350/0999 | Loss 0.0339 | Catch count 170
# Episode 0351/0999 | Loss 0.0342 | Catch count 171
# Episode 0352/0999 | Loss 0.0325 | Catch count 171
# Episode 0353/0999 | Loss 0.0241 | Catch count 171
# Episode 0354/0999 | Loss 0.0286 | Catch count 172
# Episode 0355/0999 | Loss 0.0289 | Catch count 172
# Episode 0356/0999 | Loss 0.0358 | Catch count 173
# Episode 0357/0999 | Loss 0.0395 | Catch count 174
# Episode 0358/0999 | Loss 0.0337 | Catch count 175
# Episode 0359/0999 | Loss 0.0289 | Catch count 176
# Episode 0360/0999 | Loss 0.0284 | Catch count 176
# Episode 0361/0999 | Loss 0.0280 | Catch count 177
# Episode 0362/0999 | Loss 0.0371 | Catch count 178
# Episode 0363/0999 | Loss 0.0316 | Catch count 179
# Episode 0364/0999 | Loss 0.0334 | Catch count 179
# Episode 0365/0999 | Loss 0.0327 | Catch count 180
# Episode 0366/0999 | Loss 0.0282 | Catch count 180
# Episode 0367/0999 | Loss 0.0226 | Catch count 181
# Episode 0368/0999 | Loss 0.0331 | Catch count 182
# Episode 0369/0999 | Loss 0.0305 | Catch count 183
# Episode 0370/0999 | Loss 0.0266 | Catch count 183
# Episode 0371/0999 | Loss 0.0324 | Catch count 184
# Episode 0372/0999 | Loss 0.0343 | Catch count 185
# Episode 0373/0999 | Loss 0.0225 | Catch count 185
# Episode 0374/0999 | Loss 0.0302 | Catch count 186
# Episode 0375/0999 | Loss 0.0643 | Catch count 187
# Episode 0376/0999 | Loss 0.0605 | Catch count 188
# Episode 0377/0999 | Loss 0.0403 | Catch count 188
# Episode 0378/0999 | Loss 0.0330 | Catch count 189
# Episode 0379/0999 | Loss 0.0445 | Catch count 190
# Episode 0380/0999 | Loss 0.0325 | Catch count 190
# Episode 0381/0999 | Loss 0.0341 | Catch count 191
# Episode 0382/0999 | Loss 0.0350 | Catch count 192
# Episode 0383/0999 | Loss 0.0362 | Catch count 193
# Episode 0384/0999 | Loss 0.0317 | Catch count 194
# Episode 0385/0999 | Loss 0.0328 | Catch count 194
# Episode 0386/0999 | Loss 0.0243 | Catch count 195
# Episode 0387/0999 | Loss 0.0291 | Catch count 195
# Episode 0388/0999 | Loss 0.0313 | Catch count 196
# Episode 0389/0999 | Loss 0.0374 | Catch count 196
# Episode 0390/0999 | Loss 0.0313 | Catch count 197
# Episode 0391/0999 | Loss 0.0391 | Catch count 197
# Episode 0392/0999 | Loss 0.0510 | Catch count 198
# Episode 0393/0999 | Loss 0.0512 | Catch count 199
# Episode 0394/0999 | Loss 0.0499 | Catch count 199
# Episode 0395/0999 | Loss 0.0340 | Catch count 200
# Episode 0396/0999 | Loss 0.0366 | Catch count 200
# Episode 0397/0999 | Loss 0.0334 | Catch count 201
# Episode 0398/0999 | Loss 0.0482 | Catch count 202
# Episode 0399/0999 | Loss 0.0377 | Catch count 203
# Episode 0400/0999 | Loss 0.0390 | Catch count 203
# Episode 0401/0999 | Loss 0.0435 | Catch count 203
# Episode 0402/0999 | Loss 0.0510 | Catch count 203
# Episode 0403/0999 | Loss 0.0530 | Catch count 203
# Episode 0404/0999 | Loss 0.0380 | Catch count 204
# Episode 0405/0999 | Loss 0.0405 | Catch count 205
# Episode 0406/0999 | Loss 0.0349 | Catch count 206
# Episode 0407/0999 | Loss 0.0464 | Catch count 206
# Episode 0408/0999 | Loss 0.0373 | Catch count 207
# Episode 0409/0999 | Loss 0.0521 | Catch count 208
# Episode 0410/0999 | Loss 0.0440 | Catch count 209
# Episode 0411/0999 | Loss 0.0353 | Catch count 210
# Episode 0412/0999 | Loss 0.0281 | Catch count 211
# Episode 0413/0999 | Loss 0.0326 | Catch count 212
# Episode 0414/0999 | Loss 0.0435 | Catch count 213
# Episode 0415/0999 | Loss 0.0380 | Catch count 214
# Episode 0416/0999 | Loss 0.0304 | Catch count 215
# Episode 0417/0999 | Loss 0.0322 | Catch count 215
# Episode 0418/0999 | Loss 0.0341 | Catch count 216
# Episode 0419/0999 | Loss 0.0349 | Catch count 217
# Episode 0420/0999 | Loss 0.0240 | Catch count 217
# Episode 0421/0999 | Loss 0.0220 | Catch count 217
# Episode 0422/0999 | Loss 0.0304 | Catch count 218
# Episode 0423/0999 | Loss 0.0400 | Catch count 219
# Episode 0424/0999 | Loss 0.0282 | Catch count 219
# Episode 0425/0999 | Loss 0.0382 | Catch count 220
# Episode 0426/0999 | Loss 0.0323 | Catch count 221
# Episode 0427/0999 | Loss 0.0323 | Catch count 222
# Episode 0428/0999 | Loss 0.0387 | Catch count 222
# Episode 0429/0999 | Loss 0.0275 | Catch count 223
# Episode 0430/0999 | Loss 0.0259 | Catch count 223
# Episode 0431/0999 | Loss 0.0245 | Catch count 223
# Episode 0432/0999 | Loss 0.0301 | Catch count 224
# Episode 0433/0999 | Loss 0.0423 | Catch count 224
# Episode 0434/0999 | Loss 0.0305 | Catch count 225
# Episode 0435/0999 | Loss 0.0361 | Catch count 226
# Episode 0436/0999 | Loss 0.0254 | Catch count 226
# Episode 0437/0999 | Loss 0.0224 | Catch count 227
# Episode 0438/0999 | Loss 0.0255 | Catch count 227
# Episode 0439/0999 | Loss 0.0255 | Catch count 228
# Episode 0440/0999 | Loss 0.0341 | Catch count 229
# Episode 0441/0999 | Loss 0.0311 | Catch count 230
# Episode 0442/0999 | Loss 0.0329 | Catch count 231
# Episode 0443/0999 | Loss 0.0394 | Catch count 232
# Episode 0444/0999 | Loss 0.0338 | Catch count 232
# Episode 0445/0999 | Loss 0.0405 | Catch count 232
# Episode 0446/0999 | Loss 0.0241 | Catch count 232
# Episode 0447/0999 | Loss 0.0252 | Catch count 233
# Episode 0448/0999 | Loss 0.0252 | Catch count 233
# Episode 0449/0999 | Loss 0.0336 | Catch count 234
# Episode 0450/0999 | Loss 0.0334 | Catch count 234
# Episode 0451/0999 | Loss 0.0203 | Catch count 235
# Episode 0452/0999 | Loss 0.0174 | Catch count 236
# Episode 0453/0999 | Loss 0.0245 | Catch count 236
# Episode 0454/0999 | Loss 0.0185 | Catch count 237
# Episode 0455/0999 | Loss 0.0384 | Catch count 238
# Episode 0456/0999 | Loss 0.0397 | Catch count 239
# Episode 0457/0999 | Loss 0.0510 | Catch count 240
# Episode 0458/0999 | Loss 0.0343 | Catch count 240
# Episode 0459/0999 | Loss 0.0359 | Catch count 241
# Episode 0460/0999 | Loss 0.0456 | Catch count 242
# Episode 0461/0999 | Loss 0.0216 | Catch count 243
# Episode 0462/0999 | Loss 0.0295 | Catch count 244
# Episode 0463/0999 | Loss 0.0400 | Catch count 245
# Episode 0464/0999 | Loss 0.0258 | Catch count 246
# Episode 0465/0999 | Loss 0.0301 | Catch count 247
# Episode 0466/0999 | Loss 0.0240 | Catch count 248
# Episode 0467/0999 | Loss 0.0224 | Catch count 248
# Episode 0468/0999 | Loss 0.0243 | Catch count 248
# Episode 0469/0999 | Loss 0.0228 | Catch count 248
# Episode 0470/0999 | Loss 0.0167 | Catch count 248
# Episode 0471/0999 | Loss 0.0172 | Catch count 248
# Episode 0472/0999 | Loss 0.0298 | Catch count 249
# Episode 0473/0999 | Loss 0.0241 | Catch count 250
# Episode 0474/0999 | Loss 0.0195 | Catch count 250
# Episode 0475/0999 | Loss 0.0238 | Catch count 250
# Episode 0476/0999 | Loss 0.0195 | Catch count 251
# Episode 0477/0999 | Loss 0.0207 | Catch count 252
# Episode 0478/0999 | Loss 0.0268 | Catch count 253
# Episode 0479/0999 | Loss 0.0200 | Catch count 253
# Episode 0480/0999 | Loss 0.0200 | Catch count 254
# Episode 0481/0999 | Loss 0.0253 | Catch count 255
# Episode 0482/0999 | Loss 0.0210 | Catch count 256
# Episode 0483/0999 | Loss 0.0213 | Catch count 256
# Episode 0484/0999 | Loss 0.0150 | Catch count 257
# Episode 0485/0999 | Loss 0.0222 | Catch count 257
# Episode 0486/0999 | Loss 0.0249 | Catch count 258
# Episode 0487/0999 | Loss 0.0191 | Catch count 259
# Episode 0488/0999 | Loss 0.0256 | Catch count 260
# Episode 0489/0999 | Loss 0.0173 | Catch count 261
# Episode 0490/0999 | Loss 0.0203 | Catch count 262
# Episode 0491/0999 | Loss 0.0305 | Catch count 263
# Episode 0492/0999 | Loss 0.0157 | Catch count 264
# Episode 0493/0999 | Loss 0.0209 | Catch count 264
# Episode 0494/0999 | Loss 0.0184 | Catch count 264
# Episode 0495/0999 | Loss 0.0245 | Catch count 265
# Episode 0496/0999 | Loss 0.0198 | Catch count 266
# Episode 0497/0999 | Loss 0.0249 | Catch count 267
# Episode 0498/0999 | Loss 0.0223 | Catch count 268
# Episode 0499/0999 | Loss 0.0235 | Catch count 269
# Episode 0500/0999 | Loss 0.0228 | Catch count 270
# Episode 0501/0999 | Loss 0.0231 | Catch count 271
# Episode 0502/0999 | Loss 0.0142 | Catch count 271
# Episode 0503/0999 | Loss 0.0178 | Catch count 272
# Episode 0504/0999 | Loss 0.0174 | Catch count 272
# Episode 0505/0999 | Loss 0.0251 | Catch count 273
# Episode 0506/0999 | Loss 0.0169 | Catch count 274
# Episode 0507/0999 | Loss 0.0182 | Catch count 275
# Episode 0508/0999 | Loss 0.0190 | Catch count 276
# Episode 0509/0999 | Loss 0.0216 | Catch count 277
# Episode 0510/0999 | Loss 0.0198 | Catch count 277
# Episode 0511/0999 | Loss 0.0229 | Catch count 278
# Episode 0512/0999 | Loss 0.0172 | Catch count 279
# Episode 0513/0999 | Loss 0.0206 | Catch count 280
# Episode 0514/0999 | Loss 0.0113 | Catch count 281
# Episode 0515/0999 | Loss 0.0306 | Catch count 282
# Episode 0516/0999 | Loss 0.0203 | Catch count 283
# Episode 0517/0999 | Loss 0.0226 | Catch count 284
# Episode 0518/0999 | Loss 0.0173 | Catch count 285
# Episode 0519/0999 | Loss 0.0169 | Catch count 286
# Episode 0520/0999 | Loss 0.0663 | Catch count 287
# Episode 0521/0999 | Loss 0.0561 | Catch count 288
# Episode 0522/0999 | Loss 0.0527 | Catch count 289
# Episode 0523/0999 | Loss 0.0434 | Catch count 290
# Episode 0524/0999 | Loss 0.0324 | Catch count 291
# Episode 0525/0999 | Loss 0.0395 | Catch count 291
# Episode 0526/0999 | Loss 0.0353 | Catch count 292
# Episode 0527/0999 | Loss 0.0640 | Catch count 293
# Episode 0528/0999 | Loss 0.0514 | Catch count 293
# Episode 0529/0999 | Loss 0.0323 | Catch count 294
# Episode 0530/0999 | Loss 0.0376 | Catch count 295
# Episode 0531/0999 | Loss 0.0421 | Catch count 296
# Episode 0532/0999 | Loss 0.0405 | Catch count 296
# Episode 0533/0999 | Loss 0.0315 | Catch count 296
# Episode 0534/0999 | Loss 0.0957 | Catch count 296
# Episode 0535/0999 | Loss 0.0893 | Catch count 296
# Episode 0536/0999 | Loss 0.0794 | Catch count 297
# Episode 0537/0999 | Loss 0.0605 | Catch count 298
# Episode 0538/0999 | Loss 0.0708 | Catch count 299
# Episode 0539/0999 | Loss 0.0526 | Catch count 300
# Episode 0540/0999 | Loss 0.0437 | Catch count 301
# Episode 0541/0999 | Loss 0.0519 | Catch count 302
# Episode 0542/0999 | Loss 0.0337 | Catch count 303
# Episode 0543/0999 | Loss 0.0302 | Catch count 303
# Episode 0544/0999 | Loss 0.0590 | Catch count 304
# Episode 0545/0999 | Loss 0.0480 | Catch count 304
# Episode 0546/0999 | Loss 0.0518 | Catch count 305
# Episode 0547/0999 | Loss 0.0611 | Catch count 305
# Episode 0548/0999 | Loss 0.0518 | Catch count 306
# Episode 0549/0999 | Loss 0.0638 | Catch count 307
# Episode 0550/0999 | Loss 0.0820 | Catch count 308
# Episode 0551/0999 | Loss 0.0523 | Catch count 309
# Episode 0552/0999 | Loss 0.0709 | Catch count 310
# Episode 0553/0999 | Loss 0.0442 | Catch count 311
# Episode 0554/0999 | Loss 0.0470 | Catch count 312
# Episode 0555/0999 | Loss 0.0584 | Catch count 313
# Episode 0556/0999 | Loss 0.0642 | Catch count 314
# Episode 0557/0999 | Loss 0.0494 | Catch count 315
# Episode 0558/0999 | Loss 0.0526 | Catch count 316
# Episode 0559/0999 | Loss 0.0327 | Catch count 317
# Episode 0560/0999 | Loss 0.0517 | Catch count 317
# Episode 0561/0999 | Loss 0.0492 | Catch count 318
# Episode 0562/0999 | Loss 0.0538 | Catch count 319
# Episode 0563/0999 | Loss 0.0312 | Catch count 319
# Episode 0564/0999 | Loss 0.0482 | Catch count 320
# Episode 0565/0999 | Loss 0.0364 | Catch count 321
# Episode 0566/0999 | Loss 0.0509 | Catch count 322
# Episode 0567/0999 | Loss 0.0440 | Catch count 323
# Episode 0568/0999 | Loss 0.0452 | Catch count 324
# Episode 0569/0999 | Loss 0.0369 | Catch count 325
# Episode 0570/0999 | Loss 0.0358 | Catch count 326
# Episode 0571/0999 | Loss 0.0395 | Catch count 327
# Episode 0572/0999 | Loss 0.0354 | Catch count 328
# Episode 0573/0999 | Loss 0.0320 | Catch count 329
# Episode 0574/0999 | Loss 0.0396 | Catch count 329
# Episode 0575/0999 | Loss 0.0360 | Catch count 330
# Episode 0576/0999 | Loss 0.0387 | Catch count 330
# Episode 0577/0999 | Loss 0.0469 | Catch count 331
# Episode 0578/0999 | Loss 0.0395 | Catch count 332
# Episode 0579/0999 | Loss 0.0286 | Catch count 333
# Episode 0580/0999 | Loss 0.0375 | Catch count 334
# Episode 0581/0999 | Loss 0.0261 | Catch count 335
# Episode 0582/0999 | Loss 0.0225 | Catch count 336
# Episode 0583/0999 | Loss 0.0281 | Catch count 337
# Episode 0584/0999 | Loss 0.0327 | Catch count 338
# Episode 0585/0999 | Loss 0.0286 | Catch count 339
# Episode 0586/0999 | Loss 0.0280 | Catch count 340
# Episode 0587/0999 | Loss 0.0258 | Catch count 341
# Episode 0588/0999 | Loss 0.0241 | Catch count 341
# Episode 0589/0999 | Loss 0.0301 | Catch count 342
# Episode 0590/0999 | Loss 0.0232 | Catch count 343
# Episode 0591/0999 | Loss 0.0325 | Catch count 344
# Episode 0592/0999 | Loss 0.0227 | Catch count 345
# Episode 0593/0999 | Loss 0.0377 | Catch count 346
# Episode 0594/0999 | Loss 0.0352 | Catch count 347
# Episode 0595/0999 | Loss 0.0262 | Catch count 348
# Episode 0596/0999 | Loss 0.0260 | Catch count 349
# Episode 0597/0999 | Loss 0.0270 | Catch count 350
# Episode 0598/0999 | Loss 0.0205 | Catch count 351
# Episode 0599/0999 | Loss 0.0193 | Catch count 352
# Episode 0600/0999 | Loss 0.0259 | Catch count 353
# Episode 0601/0999 | Loss 0.0312 | Catch count 354
# Episode 0602/0999 | Loss 0.0165 | Catch count 355
# Episode 0603/0999 | Loss 0.0295 | Catch count 356
# Episode 0604/0999 | Loss 0.0262 | Catch count 357
# Episode 0605/0999 | Loss 0.0260 | Catch count 358
# Episode 0606/0999 | Loss 0.0245 | Catch count 359
# Episode 0607/0999 | Loss 0.0159 | Catch count 360
# Episode 0608/0999 | Loss 0.0236 | Catch count 361
# Episode 0609/0999 | Loss 0.0166 | Catch count 362
# Episode 0610/0999 | Loss 0.0197 | Catch count 362
# Episode 0611/0999 | Loss 0.0189 | Catch count 363
# Episode 0612/0999 | Loss 0.0155 | Catch count 363
# Episode 0613/0999 | Loss 0.0190 | Catch count 364
# Episode 0614/0999 | Loss 0.0169 | Catch count 365
# Episode 0615/0999 | Loss 0.0206 | Catch count 366
# Episode 0616/0999 | Loss 0.0351 | Catch count 367
# Episode 0617/0999 | Loss 0.0259 | Catch count 368
# Episode 0618/0999 | Loss 0.0230 | Catch count 368
# Episode 0619/0999 | Loss 0.0148 | Catch count 369
# Episode 0620/0999 | Loss 0.0186 | Catch count 370
# Episode 0621/0999 | Loss 0.0329 | Catch count 371
# Episode 0622/0999 | Loss 0.0563 | Catch count 371
# Episode 0623/0999 | Loss 0.0242 | Catch count 372
# Episode 0624/0999 | Loss 0.0405 | Catch count 373
# Episode 0625/0999 | Loss 0.0615 | Catch count 374
# Episode 0626/0999 | Loss 0.0400 | Catch count 375
# Episode 0627/0999 | Loss 0.0463 | Catch count 376
# Episode 0628/0999 | Loss 0.0299 | Catch count 377
# Episode 0629/0999 | Loss 0.0508 | Catch count 378
# Episode 0630/0999 | Loss 0.0298 | Catch count 379
# Episode 0631/0999 | Loss 0.0446 | Catch count 380
# Episode 0632/0999 | Loss 0.0182 | Catch count 381
# Episode 0633/0999 | Loss 0.0277 | Catch count 382
# Episode 0634/0999 | Loss 0.0376 | Catch count 383
# Episode 0635/0999 | Loss 0.0286 | Catch count 384
# Episode 0636/0999 | Loss 0.0305 | Catch count 385
# Episode 0637/0999 | Loss 0.0267 | Catch count 386
# Episode 0638/0999 | Loss 0.0225 | Catch count 387
# Episode 0639/0999 | Loss 0.0217 | Catch count 387
# Episode 0640/0999 | Loss 0.0212 | Catch count 388
# Episode 0641/0999 | Loss 0.0277 | Catch count 389
# Episode 0642/0999 | Loss 0.0432 | Catch count 390
# Episode 0643/0999 | Loss 0.0456 | Catch count 390
# Episode 0644/0999 | Loss 0.0665 | Catch count 391
# Episode 0645/0999 | Loss 0.0426 | Catch count 392
# Episode 0646/0999 | Loss 0.0241 | Catch count 393
# Episode 0647/0999 | Loss 0.0587 | Catch count 394
# Episode 0648/0999 | Loss 0.0202 | Catch count 395
# Episode 0649/0999 | Loss 0.0502 | Catch count 396
# Episode 0650/0999 | Loss 0.0237 | Catch count 397
# Episode 0651/0999 | Loss 0.0294 | Catch count 398
# Episode 0652/0999 | Loss 0.0228 | Catch count 398
# Episode 0653/0999 | Loss 0.0240 | Catch count 399
# Episode 0654/0999 | Loss 0.0776 | Catch count 400
# Episode 0655/0999 | Loss 0.0213 | Catch count 401
# Episode 0656/0999 | Loss 0.0241 | Catch count 402
# Episode 0657/0999 | Loss 0.0606 | Catch count 403
# Episode 0658/0999 | Loss 0.0515 | Catch count 404
# Episode 0659/0999 | Loss 0.0257 | Catch count 405
# Episode 0660/0999 | Loss 0.0322 | Catch count 406
# Episode 0661/0999 | Loss 0.0332 | Catch count 407
# Episode 0662/0999 | Loss 0.0517 | Catch count 407
# Episode 0663/0999 | Loss 0.0377 | Catch count 408
# Episode 0664/0999 | Loss 0.0235 | Catch count 409
# Episode 0665/0999 | Loss 0.0465 | Catch count 409
# Episode 0666/0999 | Loss 0.0631 | Catch count 410
# Episode 0667/0999 | Loss 0.0571 | Catch count 411
# Episode 0668/0999 | Loss 0.0478 | Catch count 412
# Episode 0669/0999 | Loss 0.0389 | Catch count 412
# Episode 0670/0999 | Loss 0.0331 | Catch count 413
# Episode 0671/0999 | Loss 0.0588 | Catch count 414
# Episode 0672/0999 | Loss 0.0344 | Catch count 415
# Episode 0673/0999 | Loss 0.0637 | Catch count 415
# Episode 0674/0999 | Loss 0.0266 | Catch count 416
# Episode 0675/0999 | Loss 0.0395 | Catch count 417
# Episode 0676/0999 | Loss 0.0522 | Catch count 418
# Episode 0677/0999 | Loss 0.0276 | Catch count 419
# Episode 0678/0999 | Loss 0.0519 | Catch count 419
# Episode 0679/0999 | Loss 0.0543 | Catch count 420
# Episode 0680/0999 | Loss 0.0365 | Catch count 421
# Episode 0681/0999 | Loss 0.0459 | Catch count 422
# Episode 0682/0999 | Loss 0.0475 | Catch count 423
# Episode 0683/0999 | Loss 0.0362 | Catch count 424
# Episode 0684/0999 | Loss 0.0379 | Catch count 425
# Episode 0685/0999 | Loss 0.0310 | Catch count 426
# Episode 0686/0999 | Loss 0.0466 | Catch count 427
# Episode 0687/0999 | Loss 0.0437 | Catch count 427
# Episode 0688/0999 | Loss 0.0518 | Catch count 428
# Episode 0689/0999 | Loss 0.0349 | Catch count 429
# Episode 0690/0999 | Loss 0.0352 | Catch count 430
# Episode 0691/0999 | Loss 0.0403 | Catch count 431
# Episode 0692/0999 | Loss 0.0384 | Catch count 432
# Episode 0693/0999 | Loss 0.0350 | Catch count 433
# Episode 0694/0999 | Loss 0.0248 | Catch count 434
# Episode 0695/0999 | Loss 0.0433 | Catch count 434
# Episode 0696/0999 | Loss 0.0491 | Catch count 435
# Episode 0697/0999 | Loss 0.0466 | Catch count 436
# Episode 0698/0999 | Loss 0.0347 | Catch count 437
# Episode 0699/0999 | Loss 0.0372 | Catch count 438
# Episode 0700/0999 | Loss 0.0436 | Catch count 439
# Episode 0701/0999 | Loss 0.0300 | Catch count 440
# Episode 0702/0999 | Loss 0.0271 | Catch count 441
# Episode 0703/0999 | Loss 0.0273 | Catch count 442
# Episode 0704/0999 | Loss 0.0467 | Catch count 443
# Episode 0705/0999 | Loss 0.0273 | Catch count 444
# Episode 0706/0999 | Loss 0.0284 | Catch count 445
# Episode 0707/0999 | Loss 0.0223 | Catch count 446
# Episode 0708/0999 | Loss 0.0272 | Catch count 447
# Episode 0709/0999 | Loss 0.0282 | Catch count 448
# Episode 0710/0999 | Loss 0.0311 | Catch count 449
# Episode 0711/0999 | Loss 0.0327 | Catch count 450
# Episode 0712/0999 | Loss 0.0349 | Catch count 451
# Episode 0713/0999 | Loss 0.0354 | Catch count 452
# Episode 0714/0999 | Loss 0.0326 | Catch count 453
# Episode 0715/0999 | Loss 0.0298 | Catch count 454
# Episode 0716/0999 | Loss 0.0278 | Catch count 455
# Episode 0717/0999 | Loss 0.0290 | Catch count 456
# Episode 0718/0999 | Loss 0.0219 | Catch count 457
# Episode 0719/0999 | Loss 0.0238 | Catch count 458
# Episode 0720/0999 | Loss 0.0282 | Catch count 458
# Episode 0721/0999 | Loss 0.0324 | Catch count 459
# Episode 0722/0999 | Loss 0.0334 | Catch count 460
# Episode 0723/0999 | Loss 0.0248 | Catch count 461
# Episode 0724/0999 | Loss 0.0246 | Catch count 461
# Episode 0725/0999 | Loss 0.0308 | Catch count 462
# Episode 0726/0999 | Loss 0.0402 | Catch count 462
# Episode 0727/0999 | Loss 0.0460 | Catch count 463
# Episode 0728/0999 | Loss 0.0475 | Catch count 464
# Episode 0729/0999 | Loss 0.0433 | Catch count 465
# Episode 0730/0999 | Loss 0.0310 | Catch count 466
# Episode 0731/0999 | Loss 0.0336 | Catch count 467
# Episode 0732/0999 | Loss 0.0314 | Catch count 468
# Episode 0733/0999 | Loss 0.0337 | Catch count 469
# Episode 0734/0999 | Loss 0.0290 | Catch count 470
# Episode 0735/0999 | Loss 0.0277 | Catch count 471
# Episode 0736/0999 | Loss 0.0453 | Catch count 471
# Episode 0737/0999 | Loss 0.0288 | Catch count 472
# Episode 0738/0999 | Loss 0.0259 | Catch count 473
# Episode 0739/0999 | Loss 0.0263 | Catch count 474
# Episode 0740/0999 | Loss 0.0377 | Catch count 475
# Episode 0741/0999 | Loss 0.0222 | Catch count 476
# Episode 0742/0999 | Loss 0.0298 | Catch count 477
# Episode 0743/0999 | Loss 0.0318 | Catch count 477
# Episode 0744/0999 | Loss 0.0264 | Catch count 478
# Episode 0745/0999 | Loss 0.0243 | Catch count 479
# Episode 0746/0999 | Loss 0.0234 | Catch count 480
# Episode 0747/0999 | Loss 0.0289 | Catch count 481
# Episode 0748/0999 | Loss 0.0293 | Catch count 482
# Episode 0749/0999 | Loss 0.0293 | Catch count 483
# Episode 0750/0999 | Loss 0.0246 | Catch count 484
# Episode 0751/0999 | Loss 0.0359 | Catch count 484
# Episode 0752/0999 | Loss 0.0278 | Catch count 485
# Episode 0753/0999 | Loss 0.0285 | Catch count 486
# Episode 0754/0999 | Loss 0.0217 | Catch count 487
# Episode 0755/0999 | Loss 0.0238 | Catch count 488
# Episode 0756/0999 | Loss 0.0237 | Catch count 489
# Episode 0757/0999 | Loss 0.0264 | Catch count 490
# Episode 0758/0999 | Loss 0.0215 | Catch count 491
# Episode 0759/0999 | Loss 0.0203 | Catch count 491
# Episode 0760/0999 | Loss 0.0237 | Catch count 492
# Episode 0761/0999 | Loss 0.0168 | Catch count 493
# Episode 0762/0999 | Loss 0.0189 | Catch count 493
# Episode 0763/0999 | Loss 0.0251 | Catch count 493
# Episode 0764/0999 | Loss 0.0286 | Catch count 494
# Episode 0765/0999 | Loss 0.0257 | Catch count 495
# Episode 0766/0999 | Loss 0.0210 | Catch count 496
# Episode 0767/0999 | Loss 0.0196 | Catch count 497
# Episode 0768/0999 | Loss 0.0211 | Catch count 498
# Episode 0769/0999 | Loss 0.0199 | Catch count 499
# Episode 0770/0999 | Loss 0.0185 | Catch count 500
# Episode 0771/0999 | Loss 0.0168 | Catch count 501
# Episode 0772/0999 | Loss 0.0203 | Catch count 502
# Episode 0773/0999 | Loss 0.0180 | Catch count 503
# Episode 0774/0999 | Loss 0.0185 | Catch count 504
# Episode 0775/0999 | Loss 0.0175 | Catch count 505
# Episode 0776/0999 | Loss 0.0241 | Catch count 506
# Episode 0777/0999 | Loss 0.0192 | Catch count 507
# Episode 0778/0999 | Loss 0.0192 | Catch count 508
# Episode 0779/0999 | Loss 0.0157 | Catch count 509
# Episode 0780/0999 | Loss 0.0146 | Catch count 510
# Episode 0781/0999 | Loss 0.0132 | Catch count 511
# Episode 0782/0999 | Loss 0.0141 | Catch count 512
# Episode 0783/0999 | Loss 0.0118 | Catch count 513
# Episode 0784/0999 | Loss 0.0144 | Catch count 514
# Episode 0785/0999 | Loss 0.0115 | Catch count 515
# Episode 0786/0999 | Loss 0.0121 | Catch count 516
# Episode 0787/0999 | Loss 0.0164 | Catch count 517
# Episode 0788/0999 | Loss 0.0116 | Catch count 518
# Episode 0789/0999 | Loss 0.0151 | Catch count 519
# Episode 0790/0999 | Loss 0.0136 | Catch count 520
# Episode 0791/0999 | Loss 0.0101 | Catch count 521
# Episode 0792/0999 | Loss 0.0143 | Catch count 522
# Episode 0793/0999 | Loss 0.0089 | Catch count 523
# Episode 0794/0999 | Loss 0.0105 | Catch count 524
# Episode 0795/0999 | Loss 0.0107 | Catch count 525
# Episode 0796/0999 | Loss 0.0100 | Catch count 526
# Episode 0797/0999 | Loss 0.0098 | Catch count 527
# Episode 0798/0999 | Loss 0.0138 | Catch count 528
# Episode 0799/0999 | Loss 0.0100 | Catch count 529
# Episode 0800/0999 | Loss 0.0099 | Catch count 530
# Episode 0801/0999 | Loss 0.0089 | Catch count 531
# Episode 0802/0999 | Loss 0.0120 | Catch count 532
# Episode 0803/0999 | Loss 0.0088 | Catch count 533
# Episode 0804/0999 | Loss 0.0086 | Catch count 534
# Episode 0805/0999 | Loss 0.0096 | Catch count 535
# Episode 0806/0999 | Loss 0.0104 | Catch count 536
# Episode 0807/0999 | Loss 0.0103 | Catch count 537
# Episode 0808/0999 | Loss 0.0127 | Catch count 538
# Episode 0809/0999 | Loss 0.0107 | Catch count 539
# Episode 0810/0999 | Loss 0.0121 | Catch count 540
# Episode 0811/0999 | Loss 0.0073 | Catch count 541
# Episode 0812/0999 | Loss 0.0120 | Catch count 542
# Episode 0813/0999 | Loss 0.0116 | Catch count 543
# Episode 0814/0999 | Loss 0.0090 | Catch count 544
# Episode 0815/0999 | Loss 0.0077 | Catch count 545
# Episode 0816/0999 | Loss 0.0085 | Catch count 546
# Episode 0817/0999 | Loss 0.0090 | Catch count 547
# Episode 0818/0999 | Loss 0.0095 | Catch count 548
# Episode 0819/0999 | Loss 0.0073 | Catch count 549
# Episode 0820/0999 | Loss 0.0072 | Catch count 550
# Episode 0821/0999 | Loss 0.0101 | Catch count 551
# Episode 0822/0999 | Loss 0.0071 | Catch count 552
# Episode 0823/0999 | Loss 0.0091 | Catch count 553
# Episode 0824/0999 | Loss 0.0074 | Catch count 554
# Episode 0825/0999 | Loss 0.0088 | Catch count 555
# Episode 0826/0999 | Loss 0.0092 | Catch count 555
# Episode 0827/0999 | Loss 0.0124 | Catch count 555
# Episode 0828/0999 | Loss 0.0154 | Catch count 556
# Episode 0829/0999 | Loss 0.0159 | Catch count 557
# Episode 0830/0999 | Loss 0.0138 | Catch count 558
# Episode 0831/0999 | Loss 0.0130 | Catch count 559
# Episode 0832/0999 | Loss 0.0118 | Catch count 560
# Episode 0833/0999 | Loss 0.0109 | Catch count 561
# Episode 0834/0999 | Loss 0.0120 | Catch count 562
# Episode 0835/0999 | Loss 0.0090 | Catch count 563
# Episode 0836/0999 | Loss 0.0099 | Catch count 564
# Episode 0837/0999 | Loss 0.0074 | Catch count 565
# Episode 0838/0999 | Loss 0.0106 | Catch count 566
# Episode 0839/0999 | Loss 0.0198 | Catch count 567
# Episode 0840/0999 | Loss 0.0166 | Catch count 568
# Episode 0841/0999 | Loss 0.0096 | Catch count 569
# Episode 0842/0999 | Loss 0.0108 | Catch count 570
# Episode 0843/0999 | Loss 0.0185 | Catch count 571
# Episode 0844/0999 | Loss 0.0086 | Catch count 572
# Episode 0845/0999 | Loss 0.0192 | Catch count 573
# Episode 0846/0999 | Loss 0.0199 | Catch count 574
# Episode 0847/0999 | Loss 0.0217 | Catch count 575
# Episode 0848/0999 | Loss 0.0197 | Catch count 576
# Episode 0849/0999 | Loss 0.0155 | Catch count 577
# Episode 0850/0999 | Loss 0.0150 | Catch count 578
# Episode 0851/0999 | Loss 0.0326 | Catch count 578
# Episode 0852/0999 | Loss 0.0159 | Catch count 579
# Episode 0853/0999 | Loss 0.0216 | Catch count 580
# Episode 0854/0999 | Loss 0.0294 | Catch count 580
# Episode 0855/0999 | Loss 0.0179 | Catch count 581
# Episode 0856/0999 | Loss 0.0337 | Catch count 582
# Episode 0857/0999 | Loss 0.0155 | Catch count 583
# Episode 0858/0999 | Loss 0.0157 | Catch count 584
# Episode 0859/0999 | Loss 0.0311 | Catch count 585
# Episode 0860/0999 | Loss 0.0230 | Catch count 586
# Episode 0861/0999 | Loss 0.0142 | Catch count 587
# Episode 0862/0999 | Loss 0.0213 | Catch count 588
# Episode 0863/0999 | Loss 0.0211 | Catch count 589
# Episode 0864/0999 | Loss 0.0209 | Catch count 590
# Episode 0865/0999 | Loss 0.0144 | Catch count 591
# Episode 0866/0999 | Loss 0.0156 | Catch count 592
# Episode 0867/0999 | Loss 0.0263 | Catch count 593
# Episode 0868/0999 | Loss 0.0134 | Catch count 594
# Episode 0869/0999 | Loss 0.0184 | Catch count 594
# Episode 0870/0999 | Loss 0.0124 | Catch count 595
# Episode 0871/0999 | Loss 0.0535 | Catch count 596
# Episode 0872/0999 | Loss 0.0410 | Catch count 597
# Episode 0873/0999 | Loss 0.0097 | Catch count 598
# Episode 0874/0999 | Loss 0.0465 | Catch count 599
# Episode 0875/0999 | Loss 0.0373 | Catch count 600
# Episode 0876/0999 | Loss 0.0142 | Catch count 601
# Episode 0877/0999 | Loss 0.0228 | Catch count 602
# Episode 0878/0999 | Loss 0.0263 | Catch count 603
# Episode 0879/0999 | Loss 0.0292 | Catch count 604
# Episode 0880/0999 | Loss 0.0167 | Catch count 605
# Episode 0881/0999 | Loss 0.0151 | Catch count 606
# Episode 0882/0999 | Loss 0.0210 | Catch count 607
# Episode 0883/0999 | Loss 0.0288 | Catch count 607
# Episode 0884/0999 | Loss 0.0220 | Catch count 608
# Episode 0885/0999 | Loss 0.0243 | Catch count 609
# Episode 0886/0999 | Loss 0.0207 | Catch count 610
# Episode 0887/0999 | Loss 0.0155 | Catch count 611
# Episode 0888/0999 | Loss 0.0147 | Catch count 611
# Episode 0889/0999 | Loss 0.0171 | Catch count 612
# Episode 0890/0999 | Loss 0.0241 | Catch count 613
# Episode 0891/0999 | Loss 0.0155 | Catch count 614
# Episode 0892/0999 | Loss 0.0111 | Catch count 615
# Episode 0893/0999 | Loss 0.0132 | Catch count 616
# Episode 0894/0999 | Loss 0.0118 | Catch count 617
# Episode 0895/0999 | Loss 0.0143 | Catch count 618
# Episode 0896/0999 | Loss 0.0107 | Catch count 619
# Episode 0897/0999 | Loss 0.0138 | Catch count 619
# Episode 0898/0999 | Loss 0.0232 | Catch count 620
# Episode 0899/0999 | Loss 0.0156 | Catch count 621
# Episode 0900/0999 | Loss 0.0150 | Catch count 622
# Episode 0901/0999 | Loss 0.0120 | Catch count 623
# Episode 0902/0999 | Loss 0.0099 | Catch count 624
# Episode 0903/0999 | Loss 0.0143 | Catch count 625
# Episode 0904/0999 | Loss 0.0102 | Catch count 626
# Episode 0905/0999 | Loss 0.0150 | Catch count 627
# Episode 0906/0999 | Loss 0.0164 | Catch count 628
# Episode 0907/0999 | Loss 0.0085 | Catch count 628
# Episode 0908/0999 | Loss 0.0114 | Catch count 629
# Episode 0909/0999 | Loss 0.0120 | Catch count 630
# Episode 0910/0999 | Loss 0.0106 | Catch count 631
# Episode 0911/0999 | Loss 0.0083 | Catch count 632
# Episode 0912/0999 | Loss 0.0093 | Catch count 633
# Episode 0913/0999 | Loss 0.0096 | Catch count 634
# Episode 0914/0999 | Loss 0.0097 | Catch count 634
# Episode 0915/0999 | Loss 0.0086 | Catch count 635
# Episode 0916/0999 | Loss 0.0076 | Catch count 636
# Episode 0917/0999 | Loss 0.0091 | Catch count 637
# Episode 0918/0999 | Loss 0.0054 | Catch count 638
# Episode 0919/0999 | Loss 0.0082 | Catch count 639
# Episode 0920/0999 | Loss 0.0076 | Catch count 640
# Episode 0921/0999 | Loss 0.0267 | Catch count 641
# Episode 0922/0999 | Loss 0.0059 | Catch count 642
# Episode 0923/0999 | Loss 0.0091 | Catch count 643
# Episode 0924/0999 | Loss 0.0222 | Catch count 644
# Episode 0925/0999 | Loss 0.0081 | Catch count 645
# Episode 0926/0999 | Loss 0.0312 | Catch count 646
# Episode 0927/0999 | Loss 0.0073 | Catch count 647
# Episode 0928/0999 | Loss 0.0058 | Catch count 648
# Episode 0929/0999 | Loss 0.0174 | Catch count 649
# Episode 0930/0999 | Loss 0.0182 | Catch count 650
# Episode 0931/0999 | Loss 0.0076 | Catch count 651
# Episode 0932/0999 | Loss 0.0074 | Catch count 652
# Episode 0933/0999 | Loss 0.0049 | Catch count 653
# Episode 0934/0999 | Loss 0.0200 | Catch count 654
# Episode 0935/0999 | Loss 0.0146 | Catch count 655
# Episode 0936/0999 | Loss 0.0068 | Catch count 656
# Episode 0937/0999 | Loss 0.0056 | Catch count 657
# Episode 0938/0999 | Loss 0.0140 | Catch count 658
# Episode 0939/0999 | Loss 0.0167 | Catch count 659
# Episode 0940/0999 | Loss 0.0133 | Catch count 660
# Episode 0941/0999 | Loss 0.0099 | Catch count 661
# Episode 0942/0999 | Loss 0.0119 | Catch count 661
# Episode 0943/0999 | Loss 0.0185 | Catch count 662
# Episode 0944/0999 | Loss 0.0157 | Catch count 663
# Episode 0945/0999 | Loss 0.0182 | Catch count 664
# Episode 0946/0999 | Loss 0.0089 | Catch count 665
# Episode 0947/0999 | Loss 0.0116 | Catch count 666
# Episode 0948/0999 | Loss 0.0167 | Catch count 667
# Episode 0949/0999 | Loss 0.0092 | Catch count 668
# Episode 0950/0999 | Loss 0.0150 | Catch count 669
# Episode 0951/0999 | Loss 0.0111 | Catch count 670
# Episode 0952/0999 | Loss 0.0125 | Catch count 671
# Episode 0953/0999 | Loss 0.0124 | Catch count 672
# Episode 0954/0999 | Loss 0.0112 | Catch count 673
# Episode 0955/0999 | Loss 0.0121 | Catch count 674
# Episode 0956/0999 | Loss 0.0080 | Catch count 675
# Episode 0957/0999 | Loss 0.0098 | Catch count 676
# Episode 0958/0999 | Loss 0.0107 | Catch count 677
# Episode 0959/0999 | Loss 0.0125 | Catch count 678
# Episode 0960/0999 | Loss 0.0105 | Catch count 679
# Episode 0961/0999 | Loss 0.0109 | Catch count 680
# Episode 0962/0999 | Loss 0.0239 | Catch count 681
# Episode 0963/0999 | Loss 0.0140 | Catch count 682
# Episode 0964/0999 | Loss 0.0166 | Catch count 683
# Episode 0965/0999 | Loss 0.0155 | Catch count 684
# Episode 0966/0999 | Loss 0.0167 | Catch count 685
# Episode 0967/0999 | Loss 0.0083 | Catch count 686
# Episode 0968/0999 | Loss 0.0091 | Catch count 687
# Episode 0969/0999 | Loss 0.0127 | Catch count 688
# Episode 0970/0999 | Loss 0.0115 | Catch count 689
# Episode 0971/0999 | Loss 0.0079 | Catch count 690
# Episode 0972/0999 | Loss 0.0109 | Catch count 691
# Episode 0973/0999 | Loss 0.0111 | Catch count 692
# Episode 0974/0999 | Loss 0.0066 | Catch count 693
# Episode 0975/0999 | Loss 0.0106 | Catch count 693
# Episode 0976/0999 | Loss 0.0091 | Catch count 694
# Episode 0977/0999 | Loss 0.0102 | Catch count 695
# Episode 0978/0999 | Loss 0.0105 | Catch count 696
# Episode 0979/0999 | Loss 0.0058 | Catch count 697
# Episode 0980/0999 | Loss 0.0069 | Catch count 698
# Episode 0981/0999 | Loss 0.0087 | Catch count 699
# Episode 0982/0999 | Loss 0.0073 | Catch count 700
# Episode 0983/0999 | Loss 0.0101 | Catch count 701
# Episode 0984/0999 | Loss 0.0096 | Catch count 702
# Episode 0985/0999 | Loss 0.0066 | Catch count 703
# Episode 0986/0999 | Loss 0.0079 | Catch count 703
# Episode 0987/0999 | Loss 0.0090 | Catch count 704
# Episode 0988/0999 | Loss 0.0101 | Catch count 705
# Episode 0989/0999 | Loss 0.0077 | Catch count 706
# Episode 0990/0999 | Loss 0.0058 | Catch count 707
# Episode 0991/0999 | Loss 0.0089 | Catch count 708
# Episode 0992/0999 | Loss 0.0074 | Catch count 709
# Episode 0993/0999 | Loss 0.0086 | Catch count 710
# Episode 0994/0999 | Loss 0.0075 | Catch count 711
# Episode 0995/0999 | Loss 0.0065 | Catch count 712
# Episode 0996/0999 | Loss 0.0045 | Catch count 713
# Episode 0997/0999 | Loss 0.0055 | Catch count 714
# Episode 0998/0999 | Loss 0.0045 | Catch count 715
# Episode 0999/0999 | Loss 0.0043 | Catch count 716
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img5bc1cda4034b458da6ed516ccb570a0d">
#     <br>
#     <input id="_anim_slider5bc1cda4034b458da6ed516ccb570a0d" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim5bc1cda4034b458da6ed516ccb570a0d.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim5bc1cda4034b458da6ed516ccb570a0d.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim5bc1cda4034b458da6ed516ccb570a0d.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim5bc1cda4034b458da6ed516ccb570a0d.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim5bc1cda4034b458da6ed516ccb570a0d.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim5bc1cda4034b458da6ed516ccb570a0d.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim5bc1cda4034b458da6ed516ccb570a0d.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim5bc1cda4034b458da6ed516ccb570a0d.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim5bc1cda4034b458da6ed516ccb570a0d.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim5bc1cda4034b458da6ed516ccb570a0d.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select5bc1cda4034b458da6ed516ccb570a0d" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5bc1cda4034b458da6ed516ccb570a0d";
#     var slider_id = "_anim_slider5bc1cda4034b458da6ed516ccb570a0d";
#     var loop_select_id = "_anim_loop_select5bc1cda4034b458da6ed516ccb570a0d";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAADQZJREFUeJzt3D9oVvffx+FPfKKLqG0xosaIiqBJ\
# FEyM2KWDHVREHDSDYqGoQRAHRVy6dbJBWvxTu2RxUDBDh6YoOmgpbf2DpNqChIrQBEy0YEFtNUpM\
# ev+GB9qHR9PKr8ZzPnpdW/Dc8Q2S74tz7ttUVSqVSgBAMuOKHgAA/w0BAyAlAQMgJQEDICUBAyAl\
# AQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUB\
# AyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQED\
# IKXqogfw702dOjXmzJnzwr/v999//8K/J2RVqVSKnsD/I2CvgDlz5kR3d/cL/75VVVUv/HsCvCge\
# IQKQkoABkJKAAZCSgAGQkoCV0JkzZ2LBggUxf/78aG9vL3oOQCkJWMmMjIzEzp074/Tp09HT0xMn\
# TpyInp6eomcBlI6Alczly5dj/vz5MW/evJgwYUJs3Lgxurq6ip4FUDoCVjIDAwNRV1f359ezZs2K\
# gYGBAhcBlJP/yJxUR0dHdHR0RETEnTt3Cl4D8PK5AyuZ2trauHnz5p9f9/f3R21t7VPXbd++Pbq7\
# u6O7uztqampe5kSAUhCwklm2bFncuHEjent7Y2hoKDo7O2PdunVFzwIoHY8QS6a6ujqOHDkSq1at\
# ipGRkdi6dWs0NjYWPQugdKoqfsVyei0tLX6ZL4wxR2X5eIQIQEoCBkBKAgZASgIGQEoCBkBKAgZA\
# Sj5G/wrwcXcYe47K8nEHBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZA\
# SgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBK\
# AgZASgIGQEoCBkBKAlYyN2/ejBUrVkRDQ0M0NjbGoUOHip4EUEpVlUqlUvQI/nL79u24fft2NDc3\
# x++//x5Lly6NL774IhoaGkZ9TVVV1UtcCK8nR2X5uAMrmRkzZkRzc3NEREyaNCnq6+tjYGCg4FUA\
# 5SNgJdbX1xdXr16N5cuXFz0FoHSqix7Asz148CA2bNgQBw8ejMmTJz/15x0dHdHR0VHAMoBy8B5Y\
# CT158iTWrl0bq1atij179vzj9d4Dg7HnqCwfASuZSqUS77//frz11ltx8ODB53qNgMHYc1SWj4CV\
# zHfffRfvvPNOLF68OMaN+9+3KPft2xdr1qwZ9TUCBmPPUVk+AvYKEDAYe47K8vEpRABSEjAAUhIw\
# AFISMABSEjAAUhIwAFISMABSEjAAUhIwAFISMABSEjAAUhIwAFISMABSEjAAUhIwAFISMABSEjAA\
# UhIwAFISMABSEjAAUhIwAFISMABSEjAAUhIwAFISMABSEjAAUhIwAFISMABSEjAAUhIwAFISMABS\
# EjAAUhIwAFISMABSErCSGhkZiaampli7dm3RUwBKScBK6tChQ1FfX1/0DIDSErAS6u/vj1OnTkVb\
# W1vRUwBKS8BKaPfu3bF///4YN84/D8BonJAlc/LkyZg2bVosXbr0b6/r6OiIlpaWaGlpeUnLAMql\
# qlKpVIoewV8++OCDOHbsWFRXV8fjx4/jt99+i/Xr18fx48dHfU1VVdVLXAivJ0dl+QhYiX399dfx\
# 8ccfx8mTJ//2OgGDseeoLB+PEAFIyR3YK8AdGIw9R2X5uAMDICUBAyAlAQMgJQEDICUBAyAlAQMg\
# JQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQMgJQEDICUBAyAlAQM

# %% [markdown]
# # Possible Exercises:
# 1. Add a validation function, to make it easier to assess models.
# 1. We've been looking at convolutional neural networks for image processing. Try changing the model to use convolutional layers. Does this seem to work any better?
# 1. Change the code so that the basket is trying to avoid getting hit by the fruit.
# 1. Change the code so the game keeps going until the basket misses the fruit. (To test that this is working, you may want to change the number of games in the animation to 1.) How should this change the rewards that the model gets?
# 1. Change the game to something entirely different.
# 1. Try changing how the training works, using more of a policy gradient strategy.

# %%
class Catch(object):
    def __init__(self, grid_size=10):
        '''
        Input: grid_size (length of the side of the canvas)
        
        Initializes internal state.
        '''
        self.grid_size = grid_size
        self.min_basket_center = 1
        self.max_basket_center = self.grid_size-2
        self.catch_number = 0
        self.reset()

    def _update_state(self, action):
        '''
        Input: action (0 for left, 1 for stay, 2 for right)
        
        Moves basket according to action. Moves fruit down. Updates state to reflect these movements
        '''
        if action == 0:  # left
            movement = -1
        elif action == 1:  # stay
            movement = 0
        elif action == 2: # right
            movement = 1
        else:
            raise Exception('Invalid action {}'.format(action))
        fruit_x, fruit_y, basket_center = self.state
        # move the basket unless this would move it off the edge of the grid
        new_basket_center = min(max(self.min_basket_center, basket_center + movement), self.max_basket_center)
        # move fruit down
        fruit_y += 1
        out = np.asarray([fruit_x, fruit_y, new_basket_center])
        self.state = out

    def _draw_state(self):
        '''
        Returns a 2D numpy array with 1s (white squares) at the locations of the fruit and basket and
        0s (black squares) everywhere else.
        '''
        im_size = (self.grid_size, self.grid_size)
        canvas = np.zeros(im_size)
        
        fruit_x, fruit_y, basket_center = self.state
        canvas[fruit_y, fruit_x] = 1  # draw fruit
        canvas[-1, basket_center-1:basket_center + 2] = 1  # draw 3-pixel basket
        return canvas

    def _get_reward(self):
        '''
        Returns 1 if the fruit was caught, -1 if it was dropped, and 0 if it is still in the air, while
        tallying the number of times the fruit is caught and resetting it when it is.
        '''
        fruit_x, fruit_y, basket_center = self.state
        if fruit_y == self.grid_size-1:
            if abs(fruit_x - basket_center) == -1:
                return -1 # it dropped the fruit
            else:
                reset()
                catch_number += 1
                return 1 # it caught the fruit
        else:
            return 0 # the fruit is still in the air

    def observe(self):
        '''
        Returns the current canvas, as a 1D array.
        '''
        canvas = self._draw_state()
        return canvas.reshape((1, -1))

    def act(self, action):
        '''
        Input: action (0 for left, 1 for stay, 2 for right)
        
        Returns:
            current canvas (as a 1D array)
            reward received after this action
            True if game is over and False otherwise
        '''
        self._update_state(action)
        observation = self.observe()
        reward = self._get_reward()
        game_over = (reward == -1) # if the reward is -1, the fruit was dropped
        return observation, reward, game_over

    def reset(self):
        '''
        Updates internal state
            fruit in a random column in the top row
            basket center in a random column
        '''
        fruit_x = random.randint(0, self.grid_size-1)
        fruit_y = 0
        basket_center = random.randint(self.min_basket_center, self.max_basket_center)
        self.state = np.asarray([fruit_x, fruit_y, basket_center])


class ExperienceReplay(object):
    def __init__(self, max_memory=100, discount=.9):
        self.max_memory = max_memory
        self.memory = list()
        self.discount = discount

    def remember(self, states, game_over):
        '''
        Input:
            states: [starting_observation, action_taken, reward_received, new_observation]
            game_over: boolean
        Add the states and game over to the internal memory array. If the array is longer than
        self.max_memory, drop the oldest memory
        '''
        self.memory.append([states, game_over])
        if len(self.memory) > self.max_memory:
            del self.memory[0]

    def get_batch(self, model, batch_size=10):
        '''
        Randomly chooses batch_size memories, possibly repeating.
        For each of these memories, updates the models current best guesses about the value of taking a
            certain action from the starting state, based on the reward received and the model's current
            estimate of how valuable the new state is.
        '''
        len_memory = len(self.memory)
        num_actions = model.output_shape[-1] # the number of possible actions
        env_dim = self.memory[0][0][0].shape[1] # the number of pixels in the image
        input_size = min(len_memory, batch_size)
        inputs = np.zeros((input_size, env_dim))
        targets = np.zeros((input_size, num_actions))
        for i, idx in enumerate(np.random.randint(0, len_memory, size=input_size)):
            starting_observation, action_taken, reward_received, new_observation = self.memory[idx][0]
            game_over = self.memory[idx][1]

            # Set the input to the state that was observed in the game before an action was taken
            inputs[i:i+1] = starting_observation
            
            # Start with the model's current best guesses about the value of taking each action from this state
            targets[i] = model.predict(starting_observation)[0]
            
            # Now we need to update the value of the action that was taken                      
            if game_over: 
                # if the game is over, give the actual reward received
                targets[i, action_taken] = reward_received
            else:
                # if the game is not over, give the reward received (always zero in this particular game)
                # plus the maximum reward predicted for state we got to by taking this action (with a discount)
                Q_sa = np.max(model.predict(new_observation)[0])
                targets[i, action_taken] = reward_received + self.discount * Q_sa
        return inputs, targets
